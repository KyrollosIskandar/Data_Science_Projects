# %%
abalone_p = "abalone.data.csv"

# %%
type(abalone_p)
# Out:
# str

# %%
import pandas as pd

# %%
abalone = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'])

# %%
abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
abalone.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %%
abalone.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
y = abalone['Rings']

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
X = abalone[['Sex', 'Diameter']]

# %%
X
# Out:
#      Sex  Diameter
# 0      M     0.365
# 1      M     0.265
# 2      F     0.420
# 3      M     0.365
# 4      I     0.255
# ...   ..       ...
# 4172   F     0.450
# 4173   M     0.440
# 4174   M     0.475
# 4175   F     0.485
# 4176   M     0.555
#
# [4177 rows x 2 columns]

# %%
y.shape
# Out:
# (4177,)

# %%
X.shape
# Out:
# (4177, 2)

# %%
y.value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %%
fake_abalone = abalone.copy()

# %%
fake_abalone.loc[fake_abalone.Rings.isin([1, 2, 3]), 'Sex'] = "I "

# %%
fake_abalone['Sex'].value_counts()
# Out:
# M     1525
# I     1328
# F     1307
# I       17
# Name: Sex, dtype: int64

# %%
fake_abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
fake_abalone['Sex'] = fake_abalone['Sex'].str.strip()

# %%
fake_abalone['Sex'].value_counts()
# Out:
# M    1525
# I    1345
# F    1307
# Name: Sex, dtype: int64

# %%
fake_abalone['Sex'].replace('I', 'K', inplace=True)

# %%
# %rerun 17
# Out:
# === Executing: ===
# fake_abalone['Sex'].value_counts()
# === Output: ===
# M    1525
# K    1345
# F    1307
# Name: Sex, dtype: int64

# %%
fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22]
# Out:
#      Diameter  Rings
# 232     0.505     22
# 270     0.525     22
# 275     0.540     22
# 351     0.450     22
# 433     0.420     22
# 675     0.395     22

# %%
import numpy as np

# %%
fake_abalone.loc[fake_abalone.Rings == 22, 'Diameter'] = np.nan

# %%
# %rerun 34
# Out:
# No lines in history match specification

# %%
fake_abalone['Diameter'].fillna(fake_abalone['Diameter'].mean(axis=0), inplace=True)

# %%
# %rerun 34
# Out:
# No lines in history match specification

# %%
# %rerun 2
# Out:
# === Executing: ===
# type(abalone_p)
# === Output: ===
# str

# %%
abalone_chunks = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight',  'Rings'], 
chunksize=10)

# %%
for chunk in abalone_chunks:
    print(chunk.shape)
    print(chunk)
# Out:
# (10, 9)
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# ...

# %%
# %rerun 2
# Out:
# === Executing: ===
# type(abalone_p)
# === Output: ===
# str

# %%
abalone_iterator = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'], 
iterator=True)

# %%
print(abalone_iterator.get_chunk(10).shape)
# Out:
# (10, 9)

# %%
print(abalone_iterator.get_chunk(20).shape)
# Out:
# (20, 9)

# %%
piece = abalone_iterator.get_chunk(2)

# %%
print(piece)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 30   M    0.58      0.47   0.165        0.9975          0.3935
# 31   F    0.68      0.56   0.165        1.6390          0.6055
#
#     Viscera weight  Shell weight  Rings
# 30          0.2420          0.33     10
# 31          0.2805          0.46     15

# %%
abalone['Sex'][3]
# Out:
# 'M'

# %%
abalone.loc[3]['Sex']
# Out:
# 'M'

# %%
abalone.iloc[3]['Sex']
# Out:
# 'M'

# %%
abalone.iloc[3][0]
# Out:
# 'M'

# %%
abalone.iloc[3,0]
# Out:
# 'M'

# %%
mask_ring21 = abalone['Rings'] == 21

# %%
abalone.loc[mask_ring21,'Diameter']
# Out:
# 83      0.475
# 181     0.510
# 310     0.485
# 428     0.455
# 469     0.555
# 478     0.590
# 628     0.415
# 673     0.390
# 811     0.365
# 2180    0.420
# 2199    0.550
# 2344    0.550
# 3151    0.500
# 3930    0.535
# Name: Diameter, dtype: float64

# %%
abalone.groupby(['Rings']).mean() # Group the data by "Rings" & calculate the means.
# Out:
#          Length  Diameter    Height  Whole weight  Shucked weight  \
# Rings
# 1      0.075000  0.055000  0.010000      0.002000        0.001000
# 2      0.150000  0.100000  0.025000      0.015000        0.004500
# 3      0.176000  0.128667  0.041667      0.028400        0.011767
# 4      0.221491  0.161579  0.053947      0.059605        0.024719
# 5      0.285739  0.210696  0.069913      0.125500        0.061696
# 6      0.369363  0.278861  0.091776      0.273174        0.123158
# 7      0.422033  0.321535  0.105921      0.397386        0.182657
# 8      0.498776  0.384798  0.128556      0.640753        0.293773
# 9      0.546865  0.425218  0.142721      0.852013        0.387938
# 10     0.574629  0.449290  0.154093      1.008748        0.447217
# 11     0.599374  0.470595  0.161253      1.142559        0.503977
# 12     0.589457  0.462434  0.161292      1.102904        0.472781
# 13     0.578892  0.456453  0.160887      1.075453        0.434638
# ...

# %%
abalone.sort_values(by='Length').head(10) # Sort the data by "Length" & show the first 10 rows of the sorted data.
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1986   I   0.135     0.130   0.040        0.0290          0.0125
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
# 3899   I   0.140     0.105   0.035        0.0145          0.0050
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 2381   M   0.155     0.115   0.025        0.0240          0.0090
# 696    I   0.155     0.105   0.050        0.0175          0.0050
#
#       Viscera weight  Shell weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# ...

# %%
import matplotlib.pyplot as plt

# %%
abalone['Sex'].value_counts().plot(kind='pie',autopct='%.2f')

# %%
plt.show()

# %%
abalone['Height'].plot(kind='hist',bins=20)
plt.title('Abalone - Height info')
plt.xlabel('Height')
plt.show()

# %%
abalone['Shell weight'].plot(kind='density')
plt.title('Abalone - Shell Weight')
plt.xlabel('Shell weight')
plt.show()

# %%
abalone['Whole weight'].plot(kind='box')
plt.show()

# %%
abalone.dropna().boxplot(column='Whole weight',by='Sex')
plt.show()

# %%
abalone.plot(kind='scatter',x=8,y=2)
plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(abalone,alpha=0.2,figsize=(16,16),grid=True,diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000123A92F6108>,
# ...
#       dtype=object)

# %%
plt.show()

# %%
abalone.columns # See the index to use for accessing particular columns/attributes. Count up from 0.
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
# Log axes.
abalone.plot(kind='scatter',x=4,y=1,logx=False,logy=True)
plt.show()

# %%
# Log axes.
abalone.plot(kind='scatter',x=8,y=1,logx=False,logy=True)
plt.show()
