# %%
### The goal of my use of this data is to "identify subsets of proteins that are discriminant between the classes".
# This means to determine which proteins stand out in each of the 8 classes.

# References:
# Higuera, C, Gardiner, K J & Cios, K J (2015). Self-Organizing Feature Maps Identify Proteins Critical to Learning in a Mouse Model of Down Syndrome. PLoS ONE 10, 6 1-28.

# %%
### Load the data using the pd.read_csv() function.
import pandas as pd # I need Pandas to do this.

# %%
MouseProtein_p = "Dataset3_MiceProtein.csv" # The first step in loading the data into Jupyter Notebook.

# %%
# Now to use the pd.read_csv() function.
Proteins = ["DYRK1A_N","ITSN1_N", "BDNF_N", "NR1_N", "NR2A_N", "pAKT_N", "pBRAF_N", "pCAMKII_N", "pCREB_N", "pELK_N", "pERK_N", "pJNK_N", "PKCA_N", "pMEK_N", "pNR1_N", "pNR2A_N", "pNR2B_N", "pPKCAB_N", "pRSK_N", "AKT_N", "BRAF_N", "CAMKII_N", "CREB_N", "ELK_N", "ERK_N", "GSK3B_N", "JNK_N", "MEK_N", "TRKA_N", "RSK_N", "APP_N", "Bcatenin_N", "SOD1_N", "MTOR_N", "P38_N", "pMTOR_N", "DSCR1_N", "AMPKA_N", "NR2B_N", "pNUMB_N", "RAPTOR_N", "TIAM1_N", "pP70S6_N", "NUMB_N", "P70S6_N", "pGSK3B_N", "pPKCG_N", "CDK5_N", "S6_N", "ADARB1_N", "AcetylH3K9_N", "RRP1_N", "BAX_N", "ARC_N", "ERBB4_N", "nNOS_N", "Tau_N", "GFAP_N", "GluR3_N", "GluR4_N", "IL1B_N", "P3525_N", "pCASP9_N", "PSD95_N", "SNCA_N", "Ubiquitin_N", "pGSK3B_Tyr216_N", "SHH_N", "BAD_N", "BCL2_N", "pS6_N", "pCFOS_N", "SYP_N", "H3AcK18_N", "EGR1_N", "H3MeK4_N", "CaNA_N"]
Proteins_DF = pd.DataFrame(Proteins) # ... for checking the dimensions of the Proteins array.
Proteins_DF.shape
# Out:
# (77, 1)

# %%
Proteins
# Out:
# ['DYRK1A_N',
#  'ITSN1_N',
#  'BDNF_N',
#  'NR1_N',
#  'NR2A_N',
#  'pAKT_N',
#  'pBRAF_N',
#  'pCAMKII_N',
#  'pCREB_N',
#  'pELK_N',
#  'pERK_N',
#  'pJNK_N',
#  'PKCA_N',
#  'pMEK_N',
#  'pNR1_N',
#  'pNR2A_N',
#  'pNR2B_N',
#  'pPKCAB_N',
#  'pRSK_N',
#  'AKT_N',
#  'BRAF_N',
#  'CAMKII_N',
#  'CREB_N',
#  'ELK_N',
#  'ERK_N',
#  'GSK3B_N',
#  'JNK_N',
#  'MEK_N',
#  'TRKA_N',
#  'RSK_N',
#  'APP_N',
#  'Bcatenin_N',
#  'SOD1_N',
#  'MTOR_N',
#  'P38_N',
#  'pMTOR_N',
#  'DSCR1_N',
#  'AMPKA_N',
#  'NR2B_N',
#  'pNUMB_N',
#  'RAPTOR_N',
#  'TIAM1_N',
#  'pP70S6_N',
#  'NUMB_N',
#  'P70S6_N',
#  'pGSK3B_N',
#  'pPKCG_N',
#  'CDK5_N',
#  'S6_N',
#  'ADARB1_N',
#  'AcetylH3K9_N',
#  'RRP1_N',
#  'BAX_N',
#  'ARC_N',
#  'ERBB4_N',
#  'nNOS_N',
#  'Tau_N',
#  'GFAP_N',
#  'GluR3_N',
#  'GluR4_N',
#  'IL1B_N',
#  'P3525_N',
#  'pCASP9_N',
#  'PSD95_N',
#  'SNCA_N',
#  'Ubiquitin_N',
#  'pGSK3B_Tyr216_N',
#  'SHH_N',
#  'BAD_N',
#  'BCL2_N',
#  'pS6_N',
#  'pCFOS_N',
#  'SYP_N',
# ...

# %%
type(Proteins)
# Out:
# list

# %%
Columns = ["Mouse ID"] + Proteins + ["Genotype", "Treatment", "Behavior", "class"] # The mouse ID is actually useful. 15 measurements per mouse for each protein. The IDs are grouped in 15's.
MouseProtein = pd.read_csv(MouseProtein_p, names = Columns, skiprows = [0])
MouseProtein
# Out:
#       Mouse ID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0        309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1        309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2        309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3        309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4        309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
# ...        ...       ...       ...       ...       ...       ...       ...
# 1075  J3295_11  0.254860  0.463591  0.254860  2.092082  2.600035  0.211736
# 1076  J3295_12  0.272198  0.474163  0.251638  2.161390  2.801492  0.251274
# 1077  J3295_13  0.228700  0.395179  0.234118  1.733184  2.220852  0.220665
# 1078  J3295_14  0.221242  0.412894  0.243974  1.876347  2.384088  0.208897
# 1079  J3295_15  0.302626  0.461059  0.256564  2.092790  2.594348  0.251001
#
# ...

# %%
# Check the values of each column.
# Check for missing values.
for col_num in range(0,82):
    print("Column", col_num, "has", MouseProtein.iloc[:,col_num].value_counts().sum(), "values,", "i.e.,",
         MouseProtein.shape[0] - MouseProtein.iloc[:,col_num].value_counts().sum(), "missing values")

# There are missing values in Columns 1 - 43, 69 - 70, 72, 74 - 76. The other columns do not have missing values.
# Out:
# Column 0 has 1080 values, i.e., 0 missing values
# Column 1 has 1077 values, i.e., 3 missing values
# Column 2 has 1077 values, i.e., 3 missing values
# Column 3 has 1077 values, i.e., 3 missing values
# Column 4 has 1077 values, i.e., 3 missing values
# Column 5 has 1077 values, i.e., 3 missing values
# Column 6 has 1077 values, i.e., 3 missing values
# Column 7 has 1077 values, i.e., 3 missing values
# Column 8 has 1077 values, i.e., 3 missing values
# Column 9 has 1077 values, i.e., 3 missing values
# Column 10 has 1077 values, i.e., 3 missing values
# Column 11 has 1077 values, i.e., 3 missing values
# Column 12 has 1077 values, i.e., 3 missing values
# Column 13 has 1077 values, i.e., 3 missing values
# Column 14 has 1077 values, i.e., 3 missing values
# Column 15 has 1077 values, i.e., 3 missing values
# Column 16 has 1077 values, i.e., 3 missing values
# Column 17 has 1077 values, i.e., 3 missing values
# Column 18 has 1077 values, i.e., 3 missing values
# ...

# %%
# What are the meanings of the values that are missing?

# %%
# Make a DataFrame in which the proteins are named "Protein 1", "Protein 2", etc..
import numpy as np

Proteins_num = np.zeros((77, 1))

for num in range(1,78):
    Proteins_num[num,0] = print("Protein", str(num))

Proteins_num
# Out:
# Protein 1
# Protein 2
# Protein 3
# Protein 4
# Protein 5
# Protein 6
# Protein 7
# Protein 8
# Protein 9
# Protein 10
# Protein 11
# Protein 12
# Protein 13
# Protein 14
# Protein 15
# Protein 16
# Protein 17
# Protein 18
# Protein 19
# Protein 20
# Protein 21
# Protein 22
# Protein 23
# Protein 24
# Protein 25
# Protein 26
# Protein 27
# Protein 28
# Protein 29
# Protein 30
# Protein 31
# Protein 32
# Protein 33
# Protein 34
# Protein 35
# Protein 36
# Protein 37
# Protein 38
# Protein 39
# Protein 40
# Protein 41
# Protein 42
# Protein 43
# Protein 44
# Protein 45
# Protein 46
# Protein 47
# Protein 48
# Protein 49
# Protein 50
# Protein 51
# Protein 52
# Protein 53
# Protein 54
# Protein 55
# Protein 56
# Protein 57
# Protein 58
# Protein 59
# Protein 60
# Protein 61
# Protein 62
# Protein 63
# Protein 64
# Protein 65
# Protein 66
# Protein 67
# Protein 68
# Protein 69
# Protein 70
# Protein 71
# Protein 72
# Protein 73
# Protein 74
# Protein 75
# Protein 76
# Protein 77
# ...

# %%
type(Proteins_num)
# Out:
# numpy.ndarray

# %%
Proteins_num = Proteins_num.astype(list)

# %%
Proteins_num
# Out:
# array([[0.0],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
#        [nan],
# ...

# %%
Proteins_num_DF = pd.DataFrame(Proteins_num)
Proteins_num_DF.shape
# Out:
# (77, 1)

# %%
Columns_num = Proteins_num + ["Genotype", "Treatment", "Behavior", "class"]
MouseProtein_num = pd.read_csv(MouseProtein_p, names = Columns_num, index_col = 0, skiprows = [0])
MouseProtein_num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-04a898adc5a2> in <module>
# ----> 1 Columns_num = Proteins_num + ["Genotype", "Treatment", "Behavior", "class"]
#       2 MouseProtein_num = pd.read_csv(MouseProtein_p, names = Columns_num, index_col = 0, skiprows = [0])
#       3 MouseProtein_num
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
